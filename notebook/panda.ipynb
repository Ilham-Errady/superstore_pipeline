# %%
import pandas as pd
from sqlalchemy import create_engine

connection_string = (
    "mssql+pyodbc://sa:YourStrongPassword123!@localhost:1433/master"
    "?driver=ODBC+Driver+17+for+SQL+Server"
)

try:
    engine = create_engine(connection_string)
    with engine.connect() as conn:
        print("Connexion réussie à SQL Server !")
except Exception as e:
    print(f"Erreur de connexion : {e}")
# Out:
# Erreur de connexion : (pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][Gestionnaire de pilotes ODBC] Source de données introuvable et nom de pilote non spécifié (0) (SQLDriverConnect)')
# (Background on this error at: https://sqlalche.me/e/20/rvf5)
