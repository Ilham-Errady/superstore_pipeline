# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import time

options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

try:
    driver.get("https://www.avito.ma/fr/maroc/appartements-%C3%A0_vendre")
    time.sleep(5)       

    annonces = driver.find_elements(By.CSS_SELECTOR, "div.sc-1f93q50-0") 

    for annonce in annonces:
        try:
            titre = annonce.find_element(By.TAG_NAME, "h1").text          
            prix = annonce.find_element(By.CSS_SELECTOR, "span[data-testid='price']").text
            print(f"Appartement: {titre} | Prix: {prix}")
        except:
            continue

finally:
    driver.quit()
